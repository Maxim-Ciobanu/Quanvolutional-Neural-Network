# %% [markdown]
# ## Run the following cell if things are not installed.

# %%
# Install PennyLane and TensorFlow dependencies
!@pip install pennylane
!@pip install pennylane-tf
!@pip install tensorflow
!@pip install matplotlib
!@pip install numpy

# %% [markdown]
# # Start Here

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# Qiskit imports
import qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.quantum_info import SparsePauliOp
from qiskit.providers.basic_provider import BasicSimulator

# Check versions
import importlib
print(f"TensorFlow version: {tf.__version__}")
print(f"PennyLane version: {qml.__version__}")
print(f"Qiskit version: {qiskit.__version__}")
try:
    import qiskit_aer
    print(f"Qiskit Aer version: {qiskit_aer.__version__}")
except ImportError:
    print("Qiskit Aer not installed")
try:
    import qiskit_ibm_runtime
    print(f"Qiskit IBM Runtime version: {qiskit_ibm_runtime.__version__}")
except ImportError:
    print("Qiskit IBM Runtime not installed")
# Out:
# TensorFlow version: 2.19.0
# PennyLane version: 0.40.0
# Qiskit version: 1.2.4
# Qiskit Aer version: 0.16.0
# Qiskit IBM Runtime version: 0.29.0

# %%
################################################################################
# Setting of the main hyper-parameters of the model
#-------------------------------------------------------------------------------

n_epochs = 30    # Number of optimization epochs
n_layers = 1     # Number of random layers
n_train = 50     # Size of the train dataset
n_test = 30      # Size of the test dataset

SAVE_PATH = "quanv_data/"  # Data saving folder
# If the folder does not exist, create it
import os
os.makedirs(SAVE_PATH, exist_ok=True)

PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
################################################################################
# Loading of the MNIST dataset
#-------------------------------------------------------------------------------

mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %%
################################################################################
# Define quantum circuits for both PennyLane and Qiskit
#-------------------------------------------------------------------------------

# Random circuit parameters (shared between PennyLane and Qiskit)
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

# 1. PennyLane native implementation
dev_pennylane = qml.device("default.qubit", wires=4)

@qml.qnode(dev_pennylane)
def circuit_pennylane(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# 2. PennyLane with Qiskit backend
dev_qiskit = qml.device("qiskit.basicsim", wires=4)

@qml.qnode(dev_qiskit)
def circuit_qiskit_pl(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
################################################################################
# Quantum convolution functions for different backends
#-------------------------------------------------------------------------------

def quanv_pennylane(image):
    """Convolves the input image with PennyLane's native device."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit_pennylane(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

def quanv_qiskit_pl(image):
    """Convolves the input image with Qiskit backend through PennyLane."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit_qiskit_pl(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
################################################################################
# Quantum pre-processing of the dataset
#-------------------------------------------------------------------------------

if PREPROCESS:
    # PennyLane processing
    pl_train_images = []
    print("Quantum pre-processing of train images with PennyLane:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        pl_train_images.append(quanv_pennylane(img))
    pl_train_images = np.asarray(pl_train_images)

    pl_test_images = []
    print("\nQuantum pre-processing of test images with PennyLane:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        pl_test_images.append(quanv_pennylane(img))
    pl_test_images = np.asarray(pl_test_images)

    # Qiskit processing via PennyLane device
    qiskit_pl_train_images = []
    print("\nQuantum pre-processing of train images with Qiskit via PennyLane:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        qiskit_pl_train_images.append(quanv_qiskit_pl(img))
    qiskit_pl_train_images = np.asarray(qiskit_pl_train_images)

    qiskit_pl_test_images = []
    print("\nQuantum pre-processing of test images with Qiskit via PennyLane:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        qiskit_pl_test_images.append(quanv_qiskit_pl(img))
    qiskit_pl_test_images = np.asarray(qiskit_pl_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "pl_train_images.npy", pl_train_images)
    np.save(SAVE_PATH + "pl_test_images.npy", pl_test_images)
    np.save(SAVE_PATH + "qiskit_pl_train_images.npy", qiskit_pl_train_images)
    np.save(SAVE_PATH + "qiskit_pl_test_images.npy", qiskit_pl_test_images)

# Load pre-processed images
pl_train_images = np.load(SAVE_PATH + "pl_train_images.npy")
pl_test_images = np.load(SAVE_PATH + "pl_test_images.npy")
qiskit_pl_train_images = np.load(SAVE_PATH + "qiskit_pl_train_images.npy")
qiskit_pl_test_images = np.load(SAVE_PATH + "qiskit_pl_test_images.npy")

# %%
################################################################################
# Visualize the effect of quantum convolution with different backends
#-------------------------------------------------------------------------------

n_samples = 4
n_channels = 4
titles = ["Original", "PennyLane", "Qiskit via PennyLane"]
fig, axes = plt.subplots(1 + n_channels, n_samples * len(titles), figsize=(20, 10))

for k in range(n_samples):
    # Original image
    col = k * len(titles)
    axes[0, col].set_title(titles[0])
    axes[0, col].imshow(train_images[k, :, :, 0], cmap="gray")
    axes[0, col].set_ylabel("Input")
    
    # PennyLane processed
    col = k * len(titles) + 1
    axes[0, col].set_title(titles[1])
    for c in range(n_channels):
        if k == 0:
            axes[c + 1, col].set_ylabel(f"Output [ch. {c}]")
        axes[c + 1, col].imshow(pl_train_images[k, :, :, c], cmap="gray")
    
    # Qiskit via PennyLane
    col = k * len(titles) + 2
    axes[0, col].set_title(titles[2])
    for c in range(n_channels):
        axes[c + 1, col].imshow(qiskit_pl_train_images[k, :, :, c], cmap="gray")

# Hide empty plots in the first row 
for k in range(n_samples):
    for i in range(1, len(titles)):
        axes[0, k * len(titles) + i].axis('off')

# Hide empty plots in the first column of each channel
for k in range(n_samples):
    for i in range(1, n_channels + 1):
        axes[i, k * len(titles)].axis('off')



plt.tight_layout()
plt.show()

# %%
################################################################################
# Compare similarity between different backends
#-------------------------------------------------------------------------------

def compare_outputs(img1, img2):
    """Calculate mean squared error between two processed images"""
    return np.mean((img1 - img2)**2)

# Calculate MSE between PennyLane and Qiskit outputs
pl_qiskit_pl_mse = compare_outputs(pl_train_images, qiskit_pl_train_images)

print("Mean Squared Error between:")
print(f"PennyLane and Qiskit via PennyLane: {pl_qiskit_pl_mse:.6f}")
# Out:
# Mean Squared Error between:
# PennyLane and Qiskit via PennyLane: 0.000290

# %%
################################################################################
# Hybrid quantum-classical model
#-------------------------------------------------------------------------------

def MyModel():
    """Initializes and returns a custom Keras model which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
################################################################################
# Train and validate models on different pre-processed datasets
#-------------------------------------------------------------------------------

# PennyLane model
pl_model = MyModel()
pl_history = pl_model.fit(
    pl_train_images,
    train_labels,
    validation_data=(pl_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)

# Qiskit via PennyLane model
qiskit_pl_model = MyModel()
qiskit_pl_history = qiskit_pl_model.fit(
    qiskit_pl_train_images,
    train_labels,
    validation_data=(qiskit_pl_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)

# Classical model (no quantum pre-processing)
c_model = MyModel()
c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 58ms/step - accuracy: 0.1400 - loss: 2.7113 - val_accuracy: 0.2667 - val_loss: 2.1407
# Epoch 2/30
# 13/13 - 0s - 10ms/step - accuracy: 0.3800 - loss: 1.8890 - val_accuracy: 0.3667 - val_loss: 2.0358
# Epoch 3/30
# 13/13 - 0s - 11ms/step - accuracy: 0.6800 - loss: 1.5551 - val_accuracy: 0.3333 - val_loss: 1.9014
# Epoch 4/30
# 13/13 - 0s - 10ms/step - accuracy: 0.8000 - loss: 1.2382 - val_accuracy: 0.4667 - val_loss: 1.7143
# Epoch 5/30
# 13/13 - 0s - 11ms/step - accuracy: 0.8600 - loss: 1.0207 - val_accuracy: 0.4667 - val_loss: 1.6290
# Epoch 6/30
# 13/13 - 0s - 9ms/step - accuracy: 0.8800 - loss: 0.8502 - val_accuracy: 0.5667 - val_loss: 1.5495
# Epoch 7/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9000 - loss: 0.7155 - val_accuracy: 0.6000 - val_loss: 1.4829
# Epoch 8/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9200 - loss: 0.6085 - val_accuracy: 0.6000 - val_loss: 1.4295
# Epoch 9/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9400 - loss: 0.5222 - val_accuracy: 0.6000 - val_loss: 1.3866
# Epoch 10/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9800 - loss: 0.4518 - val_accuracy: 0.6000 - val_loss: 1.3500
# Epoch 11/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3936 - val_accuracy: 0.6000 - val_loss: 1.3184
# Epoch 12/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3451 - val_accuracy: 0.6000 - val_loss: 1.2915
# Epoch 13/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3045 - val_accuracy: 0.6000 - val_loss: 1.2681
# Epoch 14/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2703 - val_accuracy: 0.6333 - val_loss: 1.2477
# Epoch 15/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2415 - val_accuracy: 0.6333 - val_loss: 1.2297
# Epoch 16/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2169 - val_accuracy: 0.6333 - val_loss: 1.2138
# Epoch 17/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1960 - val_accuracy: 0.6667 - val_loss: 1.1997
# Epoch 18/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1780 - val_accuracy: 0.6667 - val_loss: 1.1870
# Epoch 19/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1624 - val_accuracy: 0.6667 - val_loss: 1.1756
# Epoch 20/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1489 - val_accuracy: 0.6667 - val_loss: 1.1653
# Epoch 21/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1371 - val_accuracy: 0.6667 - val_loss: 1.1560
# Epoch 22/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1267 - val_accuracy: 0.7000 - val_loss: 1.1475
# Epoch 23/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1175 - val_accuracy: 0.7000 - val_loss: 1.1397
# Epoch 24/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1094 - val_accuracy: 0.7000 - val_loss: 1.1325
# Epoch 25/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1021 - val_accuracy: 0.7000 - val_loss: 1.1259
# Epoch 26/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0956 - val_accuracy: 0.7000 - val_loss: 1.1197
# Epoch 27/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0897 - val_accuracy: 0.7000 - val_loss: 1.1141
# Epoch 28/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0844 - val_accuracy: 0.7000 - val_loss: 1.1088
# Epoch 29/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 0.7000 - val_loss: 1.1039
# Epoch 30/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0751 - val_accuracy: 0.7000 - val_loss: 1.0993
# Epoch 1/30
# 13/13 - 1s - 45ms/step - accuracy: 0.1400 - loss: 2.8027 - val_accuracy: 0.1667 - val_loss: 2.2854
# Epoch 2/30
# 13/13 - 0s - 10ms/step - accuracy: 0.2200 - loss: 2.0963 - val_accuracy: 0.2000 - val_loss: 2.0555
# Epoch 3/30
# 13/13 - 0s - 9ms/step - accuracy: 0.4400 - loss: 1.7066 - val_accuracy: 0.4000 - val_loss: 1.8438
# Epoch 4/30
# 13/13 - 0s - 9ms/step - accuracy: 0.6600 - loss: 1.3619 - val_accuracy: 0.5667 - val_loss: 1.6769
# Epoch 5/30
# 13/13 - 0s - 9ms/step - accuracy: 0.8000 - loss: 1.1178 - val_accuracy: 0.6667 - val_loss: 1.5569
# Epoch 6/30
# 13/13 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.9210 - val_accuracy: 0.7000 - val_loss: 1.4535
# Epoch 7/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9200 - loss: 0.7691 - val_accuracy: 0.7667 - val_loss: 1.3696
# Epoch 8/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.6482 - val_accuracy: 0.7667 - val_loss: 1.3001
# Epoch 9/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.5532 - val_accuracy: 0.7667 - val_loss: 1.2439
# Epoch 10/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.4764 - val_accuracy: 0.7667 - val_loss: 1.1958
# Epoch 11/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.4141 - val_accuracy: 0.8000 - val_loss: 1.1557
# Epoch 12/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.3628 - val_accuracy: 0.8000 - val_loss: 1.1221
# Epoch 13/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3203 - val_accuracy: 0.8000 - val_loss: 1.0934
# Epoch 14/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2847 - val_accuracy: 0.8000 - val_loss: 1.0689
# Epoch 15/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2547 - val_accuracy: 0.8000 - val_loss: 1.0478
# Epoch 16/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2291 - val_accuracy: 0.8000 - val_loss: 1.0294
# Epoch 17/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2072 - val_accuracy: 0.8000 - val_loss: 1.0133
# Epoch 18/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1884 - val_accuracy: 0.8000 - val_loss: 0.9991
# Epoch 19/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1721 - val_accuracy: 0.8000 - val_loss: 0.9865
# Epoch 20/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1578 - val_accuracy: 0.8000 - val_loss: 0.9753
# Epoch 21/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1453 - val_accuracy: 0.8000 - val_loss: 0.9652
# Epoch 22/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1343 - val_accuracy: 0.8000 - val_loss: 0.9561
# Epoch 23/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1246 - val_accuracy: 0.8000 - val_loss: 0.9478
# Epoch 24/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1159 - val_accuracy: 0.8000 - val_loss: 0.9403
# Epoch 25/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1082 - val_accuracy: 0.8000 - val_loss: 0.9335
# Epoch 26/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1013 - val_accuracy: 0.8000 - val_loss: 0.9272
# Epoch 27/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0950 - val_accuracy: 0.8000 - val_loss: 0.9214
# Epoch 28/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0893 - val_accuracy: 0.8000 - val_loss: 0.9160
# Epoch 29/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0842 - val_accuracy: 0.8000 - val_loss: 0.9111
# Epoch 30/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 0.8000 - val_loss: 0.9065
# Epoch 1/30
# 13/13 - 1s - 44ms/step - accuracy: 0.1400 - loss: 2.3716 - val_accuracy: 0.2000 - val_loss: 2.2814
# Epoch 2/30
# 13/13 - 0s - 9ms/step - accuracy: 0.3800 - loss: 1.9755 - val_accuracy: 0.3333 - val_loss: 2.1344
# Epoch 3/30
# 13/13 - 0s - 9ms/step - accuracy: 0.6400 - loss: 1.6968 - val_accuracy: 0.4000 - val_loss: 2.0010
# Epoch 4/30
# 13/13 - 0s - 9ms/step - accuracy: 0.7200 - loss: 1.4632 - val_accuracy: 0.4333 - val_loss: 1.8799
# Epoch 5/30
# 13/13 - 0s - 9ms/step - accuracy: 0.7800 - loss: 1.2657 - val_accuracy: 0.5000 - val_loss: 1.7734
# Epoch 6/30
# 13/13 - 0s - 9ms/step - accuracy: 0.8800 - loss: 1.0997 - val_accuracy: 0.5333 - val_loss: 1.6824
# Epoch 7/30
# 13/13 - 0s - 9ms/step - accuracy: 0.8800 - loss: 0.9606 - val_accuracy: 0.5667 - val_loss: 1.6054
# Epoch 8/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9600 - loss: 0.8441 - val_accuracy: 0.5667 - val_loss: 1.5404
# Epoch 9/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.7461 - val_accuracy: 0.6333 - val_loss: 1.4852
# Epoch 10/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.6631 - val_accuracy: 0.7000 - val_loss: 1.4378
# Epoch 11/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.5924 - val_accuracy: 0.6667 - val_loss: 1.3969
# Epoch 12/30
# 13/13 - 0s - 9ms/step - accuracy: 0.9800 - loss: 0.5319 - val_accuracy: 0.6667 - val_loss: 1.3614
# Epoch 13/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.4797 - val_accuracy: 0.6667 - val_loss: 1.3302
# Epoch 14/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.4345 - val_accuracy: 0.6667 - val_loss: 1.3029
# Epoch 15/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3952 - val_accuracy: 0.6667 - val_loss: 1.2787
# Epoch 16/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3608 - val_accuracy: 0.6667 - val_loss: 1.2572
# Epoch 17/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3306 - val_accuracy: 0.6667 - val_loss: 1.2380
# Epoch 18/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3039 - val_accuracy: 0.7000 - val_loss: 1.2208
# Epoch 19/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2803 - val_accuracy: 0.7000 - val_loss: 1.2053
# Epoch 20/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2593 - val_accuracy: 0.7000 - val_loss: 1.1913
# Epoch 21/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2405 - val_accuracy: 0.7333 - val_loss: 1.1786
# Epoch 22/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2237 - val_accuracy: 0.7000 - val_loss: 1.1671
# Epoch 23/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2086 - val_accuracy: 0.7000 - val_loss: 1.1566
# Epoch 24/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1950 - val_accuracy: 0.7000 - val_loss: 1.1470
# Epoch 25/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1827 - val_accuracy: 0.7000 - val_loss: 1.1382
# Epoch 26/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1716 - val_accuracy: 0.7000 - val_loss: 1.1302
# Epoch 27/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1614 - val_accuracy: 0.7000 - val_loss: 1.1227
# Epoch 28/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1521 - val_accuracy: 0.7000 - val_loss: 1.1159
# Epoch 29/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1437 - val_accuracy: 0.7000 - val_loss: 1.1096
# Epoch 30/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1359 - val_accuracy: 0.7000 - val_loss: 1.1037

# %%
################################################################################
# Results
#-------------------------------------------------------------------------------

import matplotlib.pyplot as plt

# plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(pl_history.history["val_accuracy"], "-ob", label="With PennyLane")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Classical (No Quantum)")
ax1.plot(qiskit_pl_history.history["val_accuracy"], "-or", label="Qiskit via PennyLane")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(pl_history.history["val_loss"], "-ob", label="With PennyLane")
ax2.plot(c_history.history["val_loss"], "-og", label="Classical (No Quantum)")
ax2.plot(qiskit_pl_history.history["val_loss"], "-or", label="Qiskit via PennyLane")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
